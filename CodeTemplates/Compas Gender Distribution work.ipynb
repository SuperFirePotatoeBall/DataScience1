# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual DataFrame)
data = {
    'Scores': [80, 90, 75, 85, 92, 78, 88, 89, 95, 82],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male']
}

df = pd.DataFrame(data)

# Calculate the percentage of each gender group for each score
percentage_df = (df.groupby(['Scores', 'Gender']).size() / df.groupby(['Scores']).size()).reset_index(name='Percentage')

# Create a bar chart with Seaborn
sns.set(style='whitegrid')
ax = sns.barplot(data=percentage_df, x='Scores', y='Percentage', hue='Gender')

# Customize the plot
ax.set(ylabel='Percentage')
plt.title('Percentage of Each Gender by Score')
plt.legend(title='Gender', loc='upper left')
plt.show()

# %%
data = {
    'Gender': ['Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'Score': [85, 90, 78, 92, 88, 76, 85, 89]
}

df = pd.DataFrame(data)
score_gender_counts = df.groupby(['Score', 'Gender']).size().unstack(fill_value=0)

# Calculate the percentage of males for each score
score_gender_percent = (score_gender_counts['Male'] / (score_gender_counts['Male'] + score_gender_counts['Female'])) * 100
sns.barplot(x=score_gender_percent.index, y=score_gender_percent.values, color='blue')
plt.xlabel('Score')
plt.ylabel('Percentage of Males')
plt.title('Percentage of Males by Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
female_df = df[df['sex'] == 'Female']

# Calculate the percentage of females for each score
score_percentages = (
    female_df['score'].value_counts(normalize=True) * 100
).reset_index(name='percentage')

# Create a bar chart using Seaborn
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.barplot(
    x='index',
    y='percentage',
    data=score_percentages,
    palette='Set2'  # You can choose a different palette
)
plt.xlabel('Score')
plt.ylabel('Percentage of Females')
plt.title('Percentage of Females by Score')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# ...
